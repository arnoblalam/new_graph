# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import tree

artificial_tree = {
1:set([2,3,4]),
2:set([5,6]),
3:set([7,9]),
4:set([10,11,12,13]),
5:set([14,16,17]),
6:set([18,19]),
7:set([20,21,23,24]),
9:set([]),
10:set([26,27]),
11:set([]),
12:set([28,29]),
13:set([]),
14:set([]),
16:set([]),
17:set([]),
18:set([]),
19:set([]),
20:set([]),
21:set([]),
23:set([]),
24:set([]),
26:set([]),
27:set([]),
28:set([]),
29:set([])
}

artificial_tree_weights ={
1: 100,
2: 20,
3: 50,
4: 80,
5: 10,
6: 30,
7: 20,
9: 400,
10:50,
11:30,
12:80,
13:60,
14:20,
16:150,
17:80,
18:40,
19:200,
20:10,
21:130,
23:80,
24:60,
26:260,
27:30,
28:40,
29:10
}

results = tree.aggregate(artificial_tree, artificial_tree_weights, 10, how_many=25, sort_type="minimum")

tree.draw_tree(artificial_tree)

# %%
results
# Out:
#       entropy  nodes  normalized_entropy  \
# 0    4.005960     25            0.862636
# 1    3.900869     24            0.850796
# 2    3.938438     24            0.858990
# 3    3.927528     24            0.856611
# 4    3.929487     24            0.857038
# 5    3.962413     24            0.864219
# 6    3.938346     24            0.858970
# 7    3.944705     24            0.860357
# 8    3.938346     24            0.858970
# 9    3.938346     24            0.858970
# 10   3.907269     24            0.852192
# 11   3.951942     24            0.861936
# 12   3.965447     24            0.864881
# 13   3.944705     24            0.860357
# 14   3.942977     24            0.859980
# 15   3.952360     24            0.862027
# 16   3.894947     24            0.849505
# 17   3.918512     24            0.854644
# 18   3.937748     24            0.858840
# 19   3.960377     24            0.863775
# 20   3.960377     24            0.863775
# 21   3.944705     24            0.860357
# ...

# %%
results.plot(x="nodes", y = "normalized_entropy")

# %%
results[results.nodes == 10]["normalized_entropy"].argmax()
# Out:
# 370

# %%
pylab.rcParams['figure.figsize'] = (15.0, 12.0)
tree.draw_tree(results.iloc[370]["tree_structure"])

# %%
results.iloc[511]["tree_structure"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-9158a0dfa95f> in <module>()
# ----> 1 results.iloc[511]["tree_structure"]
#
# C:\Users\Arnob\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1225             return self._getitem_tuple(key)
#    1226         else:
# -> 1227             return self._getitem_axis(key, axis=0)
#    1228
#    1229     def _getitem_axis(self, key, axis=0):
#
# C:\Users\Arnob\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#    1515
#    1516                 # validate the location
# -> 1517                 self._is_valid_integer(key, axis)
#    1518
#    1519             return self._get_loc(key, axis=axis)
#
# ...

# %%
results.plot(x= "nodes", y = ["entropy", "normalized_entropy"])

# %%
# ?tree.aggregate
